# %%
import pandas as pd

# %%
df = pd.read_csv('crowdedflower.csv', encoding='ISO-8859-1')
df
# Out:
#         _unit_id  relevance  relevance:variance  \
# 0      711158459       3.67               0.471
# 1      711158460       4.00               0.000
# 2      711158461       4.00               0.000
# 3      711158462       3.67               0.471
# 4      711158463       3.33               0.471
# ...          ...        ...                 ...
# 32666  713196633        NaN                 NaN
# 32667  713196634        NaN                 NaN
# 32668  713196635        NaN                 NaN
# 32669  713196636        NaN                 NaN
# 32670  713196637        NaN                 NaN
#
#                                            product_image  \
# 0      http://thumbs2.ebaystatic.com/d/l225/m/mzvzEUI...
# 1      http://thumbs3.ebaystatic.com/d/l225/m/mJNDmSy...
# 2      http://thumbs4.ebaystatic.com/d/l225/m/m10NZXA...
# 3      http://thumbs2.ebaystatic.com/d/l225/m/mZZXTmA...
# 4      http://thumbs3.ebaystatic.com/d/l225/m/mzvzEUI...
# ...

# %%
df_test = df[df['query'].isin(['coffee for nespresso',
'rice cooker', 
'nike womens', 
'plantronics corded headset',
'cowboy boots',
'Single serve coffee maker',
'lego star wars',
'flannel sheets',
'batman',
'Phillips coffee maker',
'iphone 4 case', 
'infinity scarf', 
'Cocoa Butter', 
'toddler sandals', 
'yankees',
'fuji bike shirt', 
'car window sticker',
'storage ottoman', 
'an extremely goofy movie',
'portable hard drive',
'long prom dress',
'oakley polarized radar',
'khaki pants', 
'notebook paper', 
'victoria secret pink shorts',
'playstation vita system',
'harley-davidson', 
'reusable straws', 
'glitter vials', 
'flower bulbs',
'coffee cup', 
'pencil skirt',
'nike flip flops', 
'high heels shoes', 
'yankee candle',
'candle lantern', 
'Watch women fossil',
'bike lock', 
'outdoor table cover',
'aveeno shampoo',
"leather men's briefcase",
'Brett Favre NY Titans jersey blue',
'barbie', 
'dual headset splitter',
'macbook case 13 case',
'tote bag', 
'skechers womens shoes',
'seiko monster', 
'stick vacuum', 
'flea and tick control for dogs'])]

# %%
df_test = df_test[['_unit_id', 'product_title', 'product_description', 'query', 'relevance']]

# %%
df_test
# Out:
#         _unit_id                                      product_title  \
# 175    711158634  MEN'S NWT VINTAGE REEBOK BRETT FAVRE NEW YORK ...
# 176    711158635  Reebok NFL Equipment NY Jets Brett Favre Green...
# 177    711158636  Brett Favre New York Titans NFL Equipment Reeb...
# 178    711158637  Brett Favre autographed signed NY Titans Throw...
# 179    711158638  Brett Favre NY New York Jets Wholesale NFL Foo...
# ...          ...                                                ...
# 32657  713196624  AdC raft 30 Cup 110-120V Premium Rice Cooker R...
# 32658  713196625  Zojirushi Electric Rice Cooker / Warmer - 10 c...
# 32659  713196626                    Proctor Silex 37533 Rice Cooker
# 32660  713196627  Sunpentown SC-889 10 Cup Stainless Steel Rice ...
# 32661  713196628  AdC raft 50 Cup 208V/240V Economy Rice Cooker ...
#
#                                      product_description  \
# 175                                                  NaN
# ...

# %%
df_test.dropna(subset=['product_title', 'query', 'relevance'], inplace=True)
df_test
# Out:
# <ipython-input-9-35f452331e72>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test.dropna(subset=['product_title', 'query', 'relevance'], inplace=True)
#         _unit_id                                      product_title  \
# 175    711158634  MEN'S NWT VINTAGE REEBOK BRETT FAVRE NEW YORK ...
# 176    711158635  Reebok NFL Equipment NY Jets Brett Favre Green...
# 177    711158636  Brett Favre New York Titans NFL Equipment Reeb...
# 178    711158637  Brett Favre autographed signed NY Titans Throw...
# 179    711158638  Brett Favre NY New York Jets Wholesale NFL Foo...
# ...          ...                                                ...
# 20370  711178872             Panasonic 10-Cup Rice Cooker / Steamer
# 20371  711178873   Aroma 8-Cup Digital Rice Cooker and Food Steamer
# ...
